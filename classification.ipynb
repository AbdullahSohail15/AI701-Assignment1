# %% [markdown]
# # Task 4 Classification

# %%
import pandas as pd 

df = pd.read_excel('data/default.xls', header=1, index_col='ID')
df.sample(5)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 27400     280000    1          2         1   45     -1     -1     -1     -1
# 29979     310000    1          2         1   39      0      0      0      0
# 12335     120000    2          1         2   27     -1     -1     -1     -1
# 8689       50000    1          2         2   24      0      0      0      0
# 16892     120000    1          1         2   33      1     -2     -2     -1
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID            ...
# 27400     -1  ...       1207       1207       1207      1207      1207
# 29979      0  ...     219409     216540     210675     10029      9218
# 12335     -1  ...        390        390          0       390       390
# 8689       0  ...      32945      29348      23570      6013      3011
# 16892     -1  ...        600          0          0         0         0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ID
# 27400      1207      1207      1207      1207                           0
# 29979     10029      8049      8040     10059                           0
# 12335       390       390         0       780                           0
# 8689       1019      1019      2015        17                           0
# 16892       600         0         0         0                           0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Task 4.1.1 Creating Feature matrix X and target vector y

# %%
from sklearn.model_selection import train_test_split

def get_X_y(df, test_size=0.3):
    X = df.loc[:, df.columns != 'default payment next month']
    y = df['default payment next month']

    return train_test_split(X, y, test_size=test_size, random_state=0)

X_train, X_test, y_train, y_test = get_X_y(df, test_size=0.3)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((21000, 23), (9000, 23), (21000,), (9000,))

# %% [markdown]
# # Task 4.1.2 Fit a Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

def fit_decision_tree(X_train, X_test, y_train, y_test):
    clf = DecisionTreeClassifier(max_depth=10, random_state=1)
    clf.fit(X_train, y_train)
    # predictions = clf.predict(X_test)
    scores = cross_val_score(clf, X_test, y_test, cv=5)

    return scores 

scores = fit_decision_tree(X_train, X_test, y_train, y_test)
scores.mean()
# Out:
# 0.7985555555555555

# %% [markdown]
# # Task 4.1.3 One Hot Encoding

# %%
def one_hot_encoding(df):
    categorical_cols = [
        'SEX', 'EDUCATION', 'MARRIAGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6'
    ]
    df_encoded = pd.get_dummies(df, columns=categorical_cols, dtype=int)
    return df_encoded

df_encoded = one_hot_encoding(df)
df_encoded.sample(5)
# Out:
#        LIMIT_BAL  AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# ID
# 16557     180000   27     134168     120734     124730     120423     113901
# 18555      70000   25       5412       5177       6291       9085       9270
# 8320       50000   42      46100      46949      18755      11112      11374
# 17442      30000   34      29678      28878      26758      27462      28014
# 27595      50000   34      11340      11367      10982      10243      10826
#
#        BILL_AMT6  PAY_AMT1  PAY_AMT2  ...  PAY_6_-2  PAY_6_-1  PAY_6_0  \
# ID                                    ...
# 16557     114077      4345      5966  ...         0         0        1
# 18555       6821         0      1206  ...         0         0        1
# 8320        5919      2133      1058  ...         0         1        0
# 17442      29826         0      1751  ...         0         0        1
# 27595      11699      3200      3000  ...         0         0        1
#
#        PAY_6_2  PAY_6_3  PAY_6_4  PAY_6_5  PAY_6_6  PAY_6_7  PAY_6_8
# ID
# 16557        0        0        0        0        0        0        0
# 18555        0        0        0        0        0        0        0
# 8320         0        0        0        0        0        0        0
# 17442        0        0        0        0        0        0        0
# 27595        0        0        0        0        0        0        0
#
# [5 rows x 92 columns]

# %%
scores_encoded = fit_decision_tree(*get_X_y(df_encoded, test_size=0.3))
scores_encoded.mean()
# Out:
# 0.7967777777777778

# %% [markdown]
# # Task 4.1.4 Grid Search

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    # "criterion": ["gini", "entropy", "log_loss"],
    "max_depth": range(2, 15),
    # 'max_leaf_nodes': [5, 10, 20, 100],
    'min_samples_split': [2, 5, 10, 20]
}

grid_search = GridSearchCV(
    DecisionTreeClassifier(),
    parameters, 
    cv=5, 
    scoring='accuracy',
    verbose=2,
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 52 candidates, totalling 260 fits
# [CV] END ...................max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=2; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=2, min_samples_split=5; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=10; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ..................max_depth=2, min_samples_split=20; total time=   0.0s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=3, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=3, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=4, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=4, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=5, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=7, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=7, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=7, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=7, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=7, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=7, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=7, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=7, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=7, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=5, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=7, min_samples_split=10; total time=   0.2s
# [CV] END ...................max_depth=7, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=6, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=7, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=7, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=6, min_samples_split=20; total time=   0.1s
# [CV] END ..................max_depth=7, min_samples_split=20; total time=   0.2s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.2s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.2s
# [CV] END ...................max_depth=7, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=7, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=7, min_samples_split=5; total time=   0.1s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=7, min_samples_split=10; total time=   0.1s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=7, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=9, min_samples_split=2; total time=   0.2s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.2s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=7, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=9, min_samples_split=2; total time=   0.2s
# [CV] END ...................max_depth=9, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.1s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.1s
# [CV] END ..................max_depth=9, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=9, min_samples_split=20; total time=   0.2s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.1s
# [CV] END ...................max_depth=9, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.2s
# [CV] END ...................max_depth=9, min_samples_split=5; total time=   0.2s
# [CV] END ...................max_depth=9, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.1s
# [CV] END ...................max_depth=8, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=9, min_samples_split=10; total time=   0.2s
# [CV] END ...................max_depth=9, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=9, min_samples_split=20; total time=   0.2s
# [CV] END ...................max_depth=8, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ...................max_depth=9, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=9, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=8, min_samples_split=20; total time=   0.2s
# [CV] END ...................max_depth=9, min_samples_split=2; total time=   0.1s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=9, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=9, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=9, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.2s
# [CV] END ...................max_depth=9, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=5; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=9, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=9, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=2; total time=   0.1s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=10, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=2; total time=   0.3s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.3s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=5; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=12, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=5; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=2; total time=   0.3s
# [CV] END .................max_depth=11, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=12, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=5; total time=   0.2s
# [CV] END .................max_depth=12, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=10, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=2; total time=   0.2s
# [CV] END .................max_depth=12, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=11, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=5; total time=   0.3s
# [CV] END .................max_depth=12, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=12, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=11, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=12, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=12, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=13, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=13, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=12, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=13, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=12, min_samples_split=5; total time=   0.3s
# [CV] END .................max_depth=12, min_samples_split=10; total time=   0.2s
# [CV] END ..................max_depth=13, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=13, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=13, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=13, min_samples_split=5; total time=   0.3s
# [CV] END ..................max_depth=13, min_samples_split=5; total time=   0.2s
# [CV] END .................max_depth=12, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=13, min_samples_split=5; total time=   0.3s
# [CV] END ..................max_depth=13, min_samples_split=5; total time=   0.3s
# [CV] END .................max_depth=13, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=13, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=13, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=13, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=13, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=13, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=13, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=13, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=13, min_samples_split=20; total time=   0.3s
# [CV] END .................max_depth=13, min_samples_split=20; total time=   0.2s
# [CV] END ..................max_depth=14, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=14, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=14, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=14, min_samples_split=2; total time=   0.2s
# [CV] END ..................max_depth=14, min_samples_split=2; total time=   0.3s
# [CV] END ..................max_depth=14, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=14, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=14, min_samples_split=5; total time=   0.3s
# [CV] END ..................max_depth=14, min_samples_split=5; total time=   0.2s
# [CV] END ..................max_depth=14, min_samples_split=5; total time=   0.3s
# [CV] END .................max_depth=14, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=14, min_samples_split=10; total time=   0.3s
# [CV] END .................max_depth=14, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=14, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=14, min_samples_split=10; total time=   0.2s
# [CV] END .................max_depth=14, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=14, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=14, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=14, min_samples_split=20; total time=   0.2s
# [CV] END .................max_depth=14, min_samples_split=20; total time=   0.2s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(2, 15),
#                          'min_samples_split': [2, 5, 10, 20]},
#              scoring='accuracy', verbose=2)

# %%
results = pd.DataFrame(grid_search.cv_results_)
results = results.sort_values('rank_test_score')
results.iloc[0, :]

# Best min_samples_split=2
# Best max_depth=3
# Out:
# mean_fit_time                                              0.054485
# std_fit_time                                               0.001228
# mean_score_time                                            0.001466
# std_score_time                                             0.000461
# param_max_depth                                                   3
# param_min_samples_split                                           2
# params                     {'max_depth': 3, 'min_samples_split': 2}
# split0_test_score                                          0.822857
# split1_test_score                                          0.825952
# split2_test_score                                          0.818333
# split3_test_score                                          0.814048
# split4_test_score                                          0.815238
# mean_test_score                                            0.819286
# std_test_score                                             0.004515
# rank_test_score                                                   1
# Name: 4, dtype: object

# %% [markdown]
# Other preprocessing methods that could improve the result include scaling the numerical values
